# %% [markdown]
# # Exploration Notebook
# Use this to explore data and prototype your ML pipeline.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load your data here
# df = pd.read_csv('../data/sample/data.csv')
print('Ready to explore!')
